# %% [markdown]
# <a href="https://colab.research.google.com/github/TowsifTazwar/data-science-research/blob/main/First_Program_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Welcome")
# Out:
# Welcome

# %%
print ("Name: Md. Towsif Tazwar Hussain")
# Out:
# Name: Md. Towsif Tazwar Hussain
