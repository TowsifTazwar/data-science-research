# %% [markdown]
# <a href="https://colab.research.google.com/github/TowsifTazwar/data-science-research/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 1: Write a program to perform the subtraction, multipllication and division

#Subtraction
num1 = 145.89
num2 = 345.568

sub = num2 - num1
print(f"Value: {sub}")

#Multiplication
num1 = 50
num2 = 40

mult = num1 * num2
print(f"Value: {mult}")


# Division
num1 = 90
num2 = 30

div = num1 / num2
print(f"Value: {div}")

#Division
num1 = 90
num2 = 30

div = num1 // num2
print(f"Value: {div}")
# Out:
# Value: 199.678
# Value: 2000
# Value: 3.0
# Value: 3

# %%
## 2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.



Id= 11
name= "Towsif Tazwar"
batch= 22
hometown= "cumilla"

print(f"Id: {Id}, Name: {name}, Batch: {batch}, Hometown: {hometown}")
# Out:
# Id: 11, Name: Towsif Tazwar, Batch: 22, Hometown: cumilla

# %%
## 3: Write a program to change values of an integer variable

sum= 40
print("Before: ", sum)

sum = 50

print("After: ", sum)
# Out:
# Before:  40
# After:  50

# %%
## 4: Write a program to take two string numbers and convert them to integers using explicit type conversion.


num1="50"
num2="40"

print(int(num1) + int(num2))
# Out:
# 90

# %%
## 5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.

num1=40
num2=50
num3=30

avg= (num1+num2+num3) / 3

print(f"{avg:.2f}")
# Out:
# 40.00

# %%
## 6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.


print("Calculator")

num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if operator == "+":
    result = num1 + num2
elif operator == "-":
    result = num1 - num2
elif operator == "*":
    result = num1 * num2
elif operator == "/":
    if num2 == 0:
        result = "Error: Undefined"
    else:
        result = num1 / num2
else:
    result = "Invalid"

print("Result:", result)
# Out:
# Calculator
# Enter first number: 20
# Enter operator (+, -, *, /): +
# Enter second number: 20
# Result: 40.0

# %%
## 7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant.

char = input("Enter a single character: ")

if char in "aeiou":
    print("vowel")
else:
    print("consonant")
# Out:
# Enter a single character: a
# vowel

# %%
## 8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.

print("Temperature Converter")
print("1. Celsius to Fahrenheit")
print("2. Fahrenheit to Celsius")

choice = input("Enter choice (1/2): ")

temp = float(input("Enter temperature: "))

if choice == "1":
    result = (temp * 9/5) + 32
    print("Temperature in Fahrenheit:", result)

elif choice == "2":
    result = (temp - 32) * 5/9
    print("Temperature in Celsius:", result)

else:
    print("Invalid choice")
# Out:
# Temperature Converter
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Enter choice (1/2): 1
# Enter temperature: 40
# Temperature in Fahrenheit: 104.0

# %%
## 9: Write a program that asks the user to enter three numbers and determines which one is the largest.


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))


if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

print("The largest number is:", largest)
# Out:
# Enter first number: 20
# Enter second number: 30
# Enter third number: 50
# The largest number is: 50.0

# %%
# 10: Write a program that prompts the user to input a number N and prints all even numbers between 1 and N using a for loop.


N = int(input("Enter a number: "))


for i in range(1,N):
    if i % 2 == 0:
        print(i)
# Out:
# Enter a number: 10
# 2
# 4
# 6
# 8

# %%
# 11: Write a program that prompts the user to input a number N and calculates the sum of all numbers from 1 to N that are divisible by 3 or 5.



N = int(input("Enter a number: "))

sum = 0


for i in range(1, N):
    if i % 3 == 0 or i % 5 == 0:
        sum += i
        print(i)

print("Sum:", sum)
# Out:
# Enter a number: 10
# 3
# 5
# 6
# 9
# Sum: 23

# %%
# 12: Write a program that prompts the user to input a number n and prints the multiplication table of n (1 to 10) using a for loop.


n = int(input("Enter a number: "))


for i in range(1, 11):
    print(n, "x", i, "=", n * i)
# Out:
# Enter a number: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
