# %% [markdown]
# <a href="https://colab.research.google.com/github/TowsifTazwar/data-science-research/blob/main/numpy_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings; warnings.filterwarnings('ignore')


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## 1- NumPy
#Given arr = np.random.randint(1, 101, 20):

#Print its sum, min, and max.
#Create a second array of the same size and multiply them element-wise.


import numpy as np

arr = np.random.randint(1, 101, 20)

print("Array:", arr)
print("Sum:", np.sum(arr))
print("Min:", np.min(arr))
print("Max:", np.max(arr))


arr2 = np.random.randint(1, 101, 20)

result = arr * arr2

print("Second Array:", arr2)
print("Element wise Multiplication:", result)
# Out:
# Array: [24 87 37 37 24 71 59 27 46 67 20 98 70 65 25 65 91 88 32 35]
# Sum: 1068
# Min: 20
# Max: 98
# Second Array: [48 38 20 87 98 45 74 63 19 18 25 51 80 34  6 11 60 80 35 64]
# Element wise Multiplication: [1152 3306  740 3219 2352 3195 4366 1701  874 1206  500 4998 5600 2210
#   150  715 5460 7040 1120 2240]

# %%
##Pandas

#Get a recent unique dataset from Kaggle or another source and compute basic statistics using Pandas

#Choose a dataset — Download a current dataset from Kaggle
#Load the dataset into a Pandas DataFrame.
#Explore and inspect the data with Pandas methods.
#Compute and display basic statistical summaries, including: Descriptive statistics (describe), Missing value counts, Data types, Class balance (if applicable), Unique values and distributions.

# %%
file_path = '/content/drive/MyDrive/Datasets/online_vs_offline_learning_dataset.csv'

df = pd.read_csv(file_path)   # raw CSV has no header
print('Loaded:', df.shape)
# Out:
# Loaded: (1000, 6)

# %%
df.head()
# Out:
#   Learning_Mode  Subject  Study_Hours  Retention_Score  Focus_Level  \
# 0       Offline  English          7.7               51           96
# 1       Offline  English          6.2               90           82
# 2        Online  English          1.2               75           66
# 3        Online     Math          6.5               80           64
# 4        Online  English          5.5               95           58
#
#    Exam_Score
# 0          70
# 1          81
# 2          71
# 3          77
# 4          78

# %%
df.tail()
# Out:
#     Learning_Mode  Subject  Study_Hours  Retention_Score  Focus_Level  \
# 995        Online     Math          7.5               57           81
# 996       Offline  History          7.8               93           79
# 997        Online     Math          5.4               55           63
# 998       Offline  English          2.3               68           59
# 999        Online  English          4.7               69           51
#
#      Exam_Score
# 995          61
# 996          88
# 997          55
# 998          59
# 999          58

# %%
df.describe()
# Out:
#        Study_Hours  Retention_Score  Focus_Level   Exam_Score
# count  1000.000000       1000.00000  1000.000000  1000.000000
# mean      4.563500         72.69100    71.261000    71.675000
# std       2.000115         17.69827    18.053166    12.984297
# min       1.000000         40.00000    40.000000    39.000000
# 25%       2.800000         58.00000    56.000000    62.000000
# 50%       4.700000         72.00000    72.000000    72.000000
# 75%       6.300000         88.00000    87.000000    81.000000
# max       8.000000        100.00000   100.000000   100.000000

# %%
df.describe(include='all')
# Out:
#        Learning_Mode  Subject  Study_Hours  Retention_Score  Focus_Level  \
# count           1000     1000  1000.000000       1000.00000  1000.000000
# unique             2        5          NaN              NaN          NaN
# top          Offline  Science          NaN              NaN          NaN
# freq             500      215          NaN              NaN          NaN
# mean             NaN      NaN     4.563500         72.69100    71.261000
# std              NaN      NaN     2.000115         17.69827    18.053166
# min              NaN      NaN     1.000000         40.00000    40.000000
# 25%              NaN      NaN     2.800000         58.00000    56.000000
# 50%              NaN      NaN     4.700000         72.00000    72.000000
# 75%              NaN      NaN     6.300000         88.00000    87.000000
# max              NaN      NaN     8.000000        100.00000   100.000000
#
#          Exam_Score
# count   1000.000000
# unique          NaN
# top             NaN
# ...

# %%
print('Missing per column:\n', df.isnull().sum(), sep='')
# Out:
# Missing per column:
# Learning_Mode      0
# Subject            0
# Study_Hours        0
# Retention_Score    0
# Focus_Level        0
# Exam_Score         0
# dtype: int64

# %%
#2-Pandas
#Create a 5×3 DataFrame of random integers (1–100) with columns A, B, C. Print the sum and mean of each column.

import numpy as np
import pandas as pd


data = np.random.randint(1, 101, (5, 3))
df = pd.DataFrame(data, columns=['A', 'B', 'C'])


print("DataFrame:\n", df)

print("\nColumn-wise Sum:\n", df.sum())
print("\nColumn-wise Mean:\n", df.mean())
# Out:
# DataFrame:
#      A   B   C
# 0  36  16  78
# 1  96  61  49
# 2  12  46  25
# 3  75  65  49
# 4  58  95  96
#
# Column-wise Sum:
#  A    277
# B    283
# C    297
# dtype: int64
#
# Column-wise Mean:
#  A    55.4
# B    56.6
# C    59.4
# dtype: float64
